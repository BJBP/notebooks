# %% [markdown]
# ## 1. Librerias

# %%
# !pip install matplotlib mahotas opencv-python scikit-image
# Out:
# Requirement already satisfied: matplotlib in c:\users\bjbp\.conda\envs\pevico\lib\site-packages (3.9.0)
# Requirement already satisfied: mahotas in c:\users\bjbp\.conda\envs\pevico\lib\site-packages (1.4.15)
# Requirement already satisfied: opencv-python in c:\users\bjbp\.conda\envs\pevico\lib\site-packages (4.9.0.80)
# Requirement already satisfied: scikit-image in c:\users\bjbp\.conda\envs\pevico\lib\site-packages (0.23.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bjbp\.conda\envs\pevico\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\bjbp\.conda\envs\pevico\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bjbp\.conda\envs\pevico\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\bjbp\.conda\envs\pevico\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\bjbp\.conda\envs\pevico\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\bjbp\.conda\envs\pevico\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\bjbp\.conda\envs\pevico\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\bjbp\.conda\envs\pevico\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bjbp\.conda\envs\pevico\lib\site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: scipy>=1.9 in c:\users\bjbp\.conda\envs\pevico\lib\site-packages (from scikit-image) (1.13.0)
# Requirement already satisfied: networkx>=2.8 in c:\users\bjbp\.conda\envs\pevico\lib\site-packages (from scikit-image) (3.3)
# Requirement already satisfied: imageio>=2.33 in c:\users\bjbp\.conda\envs\pevico\lib\site-packages (from scikit-image) (2.34.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\bjbp\.conda\envs\pevico\lib\site-packages (from scikit-image) (2024.5.10)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\bjbp\.conda\envs\pevico\lib\site-packages (from scikit-image) (0.4)
# Requirement already satisfied: six>=1.5 in c:\users\bjbp\.conda\envs\pevico\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpi
from PIL import Image
import mahotas
import mahotas.demos
# %matplotlib inline

# %% [markdown]
# ## 2. Lectura

# %% [markdown]
# ### 2.1. Lectura de imagen en escala de grises con opencv

# %%
def mostrar_imagen(location, title, use_opencv=False):
    imagen = cv2.imread(location)
    if use_opencv:
        cv2.imshow(title, imagen)
        cv2.waitKey(0)
        cv2.destroyAllWindows()
    else:
        imagen = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)  # Convertir BGR a RGB
        plt.figure(figsize=(3,3))
        plt.imshow(imagen)
        plt.title(title)
        plt.axis("off")


location = "./imagenes/barbara.png"
mostrar_imagen(location, "Mostrar con matplotlib")
mostrar_imagen(location, "Mostrar con opencv", use_opencv=True)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[4], line 16
#      12         plt.axis("off")
#      15 location = "./imagenes/barbara.png"
# ---> 16 mostrar_imagen(location, "Mostrar con matplotlib")
#      17 mostrar_imagen(location, "Mostrar con opencv", use_opencv=True)
#
# Cell In[4], line 8, in mostrar_imagen(location, title, use_opencv)
#       6     cv2.destroyAllWindows()
#       7 else:
# ----> 8     imagen = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)  # Convertir BGR a RGB
#       9     plt.figure(figsize=(3,3))
#      10     plt.imshow(imagen)
#
# error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %% [markdown]
# ### 2.2. Lectura de imagen a color con opencv

# %%
x = "./imagenes/_lena.png"
mostrar_imagen(x, "Mostrar con matplotlib")

# %% [markdown]
# ### 2.3. Lectura de imagenes con matplotlib

# %%
imagen = mpi.imread('./imagenes/_lena.png')
plt.figure(figsize=(3,3))
plt.imshow(imagen)
plt.title("Leer y mostrar con matplotlib")
plt.axis("off")

# %% [markdown]
# ### 2.4. Lectura de imagenes con PIL

# %%
im = Image.open('./imagenes/_lena.png')
im.show()

# %% [markdown]
# ### 2.5. Lectura de archivo de video

# %%
# Función y código para lectura de video omitidos por brevedad

# %% [markdown]
# ### 2.6. Lectura de video en tiempo real

# %%
# Código para captura de video en tiempo real omitido por brevedad

# %% [markdown]
# ## 3. Crear y grabar

# %% [markdown]
# ### 3.1. Imagen en escala de grises

# %%
# Código para crear imagen en escala de grises omitido por brevedad

# %% [markdown]
# ### 3.2. Imagen a color

# %%
# Código para crear imagen a color omitido por brevedad

# %% [markdown]
# ### 3.3. Grabar imagen

# %%
# Código para grabar imagen omitido por brevedad

# %% [markdown]
# ### 3.4. Grabar video

# %%
# Código para grabar video omitido por brevedad

# %% [markdown]
# ## 4.Estructura de una imagen

# %% [markdown]
# ### 4.1. Tamaño de la imagen.

# %%
def mostrar_info_imagen(location):
    imagen = cv2.imread(location)
    plt.figure(figsize=(3,3))
    plt.imshow(cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB))
    plt.axis("off")
    print(imagen.dtype)
    print('Dimension:', imagen.shape[0], 'x', imagen.shape[1])
    print('Resolución:', imagen.shape[0] * imagen.shape[1])

location = "./imagenes/_lena.png"
mostrar_info_imagen(location)
