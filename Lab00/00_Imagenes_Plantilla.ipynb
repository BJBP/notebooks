# %% [markdown]
# # Manipulación de Imagenes

# %% [markdown]
# ## 1. Librerias

# %%
# !pip install matplotlib
# !pip install mahotas
# !pip install cv
# !pip install scikit-image
# !pip install opencv-python

# %%
import numpy as np
import cv2 as cv2
import io as io
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpi
from PIL import Image
import mahotas
import mahotas.demos

# %% [markdown]
# ## 2. Lectura

# %% [markdown]
# ### 2.1. Lectura de imagen en escala de grises con opencv

# %%
location="../imagenes/barbara.png"
imagen= cv2.imread(location)

plt.figure(figsize=(3,3))
plt.imshow(imagen)
plt.title("Mostrar con matplotlib")
plt.axis("off")
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %% [markdown]
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# location="../imagenes/barbara.png"
# imagen= cv2.imread(location)

# cv2.imshow('Mostrar con opencv',imagen)
# cv2.waitKey(0)
# cv2.destroyAllWindows() # Para cerrar ventana

# %% [markdown]
# ### 2.2. Lectura de imagen a color con opencv

# %%
x="../imagenes/_lena.png"
imagen = cv2.imread(x)
imagen2 = cv2.imread(x,0)

plt.figure(figsize=(9,3))
plt.subplot(1,3,1)
plt.imshow(imagen)
plt.axis("off")
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
# Mostrar la imagen usando opencv. Además puede usar hconcat([,,]), resize y putText
x="../imagenes/_lena.png"
imagen = cv2.imread(x)
imagen2 = cv2.imread(x,0)

# Agregar codigo para obtener el resultado esperado

# %% [markdown]
# #### OpenCV

# %%
# location="../imagenes/barbara.png"
# imagen= cv2.imread(location)

# cv2.imshow('Mostrar con opencv',imagen)
# cv2.waitKey(0)
# cv2.destroyAllWindows() # Para cerrar ventana

# %%
import cv2

# %%
# Leer la imagen en BGR y escala de grises
x = "../imagenes/_lena.png"
imagen = cv2.imread(x)
imagen2 = cv2.imread(x, 0)
plt.imshow(imagen)
plt.show()
cv2.imshow('Imagenes Concatenadas', imagen)
cv2.waitKey(0)
cv2.destroyAllWindows() # Para cerrar ventana

# Convertir la imagen BGR a RGB
imagen_rgb = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)
cv2.imshow('Imagenes Concatenadas', imagen_rgb)
cv2.waitKey(0)
cv2.destroyAllWindows() # Para cerrar ventana

# %%
# Leer la imagen en BGR y escala de grises
x = "../imagenes/_lena.png"
imagen = cv2.imread(x)
imagen2 = cv2.imread(x, 0)

# Convertir la imagen de escala de grises a BGR para poder concatenar con las otras
imagen_gris_bgr = cv2.cvtColor(imagen2, cv2.COLOR_GRAY2BGR)

# Convertir la imagen BGR a RGB
imagen_rgb = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)

# Redimensionar las imágenes al 50% de su tamaño original
ancho = int(imagen.shape[1] * 0.5)
alto = int(imagen.shape[0] * 0.5)
dimensiones = (ancho, alto)

imagen_bgr_pequena = cv2.resize(imagen, dimensiones)
imagen_gris_bgr_pequena = cv2.resize(imagen_gris_bgr, dimensiones)
imagen_rgb_pequena = cv2.resize(imagen_rgb, dimensiones)

# Concatenar las imágenes en una sola ventana
imagen_concatenada = cv2.hconcat([imagen_bgr_pequena, imagen_gris_bgr_pequena, imagen_rgb_pequena])
#imagen_concatenada = cv2.resize(imagen_concatenada, dimensiones)
# Agregar texto a cada imagen
cv2.putText(imagen_concatenada, 'BGR', (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
cv2.putText(imagen_concatenada, 'Escala de Grises', (ancho + 10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
cv2.putText(imagen_concatenada, 'RGB', (ancho * 2 + 10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)

# Mostrar la imagen concatenada
cv2.imshow('Imagenes Concatenadas', imagen_concatenada)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# import cv2

# # Leer la imagen en color y en escala de grises
# x = "../imagenes/_lena.png"
# imagen_color = cv2.imread(x)
# imagen2 = cv2.imread(x, 0)

# # Convertir la imagen en escala de grises a BGR para poder concatenar con la imagen en color
# imagen_gris_bgr = cv2.cvtColor(imagen2, cv2.COLOR_GRAY2BGR)

# # Redimensionar imágenes para que tengan el mismo tamaño
# ancho = imagen_color.shape[1]  # Usar el ancho de la imagen en color
# alto = imagen_color.shape[0]  # Usar el alto de la imagen en color
# imagen_gris_bgr = cv2.resize(imagen_gris_bgr, (ancho, alto))

# # Concatenar las imágenes horizontalmente
# imagen_concatenada = cv2.hconcat([imagen_color, imagen_gris_bgr])

# # Agregar texto a la imagen concatenada
# texto = 'Color a la izquierda, Escala de grises a la derecha'
# posicion = (10, 30)  # Posición del texto
# fuente = cv2.FONT_HERSHEY_SIMPLEX  # Fuente del texto
# escala_fuente = 1  # Escala de la fuente
# color = (0, 255, 0)  # Color del texto en BGR (verde)
# grosor = 2  # Grosor del texto
# cv2.putText(imagen_concatenada, texto, posicion, fuente, escala_fuente, color, grosor)

# # Mostrar la imagen concatenada
# cv2.imshow('Imagen Concatenada', imagen_concatenada)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
# import cv2
# import numpy as np

# # Leer la imagen en color y en escala de grises
# x = "../imagenes/_lena.png"
# imagen_color = cv2.imread(x)
# imagen2 = cv2.imread(x, cv2.IMREAD_GRAYSCALE)

# # Convertir la imagen de escala de grises a BGR para poder concatenar con las otras
# imagen_gris_bgr = cv2.cvtColor(imagen2, cv2.COLOR_GRAY2BGR)

# # Convertir la imagen BGR a RGB
# imagen_rgb = cv2.cvtColor(imagen_color, cv2.COLOR_BGR2RGB)

# # Concatenar las imágenes horizontalmente
# imagenes_concatenadas = np.hstack((imagen_color, imagen_gris_bgr, imagen_rgb))

# # Agregar texto a cada imagen
# cv2.putText(imagenes_concatenadas, 'BGR', (200, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
# cv2.putText(imagenes_concatenadas, 'Escala de Grises', (600, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
# cv2.putText(imagenes_concatenadas, 'RGB', (1300, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)

# # Mostrar las imágenes concatenadas en una ventana
# cv2.imshow('Imagenes en diferentes espacios de color', imagenes_concatenadas)

# # Esperar a que se presione una tecla para cerrar la ventana
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
import cv2
import matplotlib.pyplot as plt

# Cargar la imagen
x = "../imagenes/_lena.png"
imagen = cv2.imread(x)

# Convertir la imagen a grises
imagen2 = cv2.imread(x, 0)

# Convertir la imagen grises a BGR
imagen3 = cv2.cvtColor(imagen2, cv2.COLOR_GRAY2BGR)

# Convertir la imagen BGR a RGB
imagen4 = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)

# Crear una figura con 3x1 subplots y apagar los ejes
fig, axs = plt.subplots(1, 4, figsize=(15, 5))

# Iterar a través de la lista de imágenes para mostrar
for i, img in enumerate([imagen2, imagen, imagen3, imagen4]):
    # Mostrar la imagen en el subplot correspondiente
    axs[i].imshow(img)
    # Agregar texto en la parte superior de la imagen
    axs[i].text(0.5, 0.95, f'Imagen {i+1}', ha='center', va='center', transform=axs[i].transAxes, fontsize=12, fontweight=0, color='white')
    # Apagar los ejes para el subplot
    axs[i].axis('off')

# Agregar un título a la ventana
plt.suptitle('Imagen en RGB, BGR y escala de grises', fontsize=16, fontweight=0)

plt.show()

# %%
# import cv2
# import numpy as np

# # Leer la imagen en color y en escala de grises
# x = "../imagenes/_lena.png"
# imagen_color = cv2.imread(x)
# imagen2 = cv2.imread(x, 0)

# # Convertir la imagen de BGR a RGB
# imagen_rgb = cv2.cvtColor(imagen_color, cv2.COLOR_BGR2RGB)

# # Redimensionar las imágenes para que tengan el mismo tamaño
# altura, ancho = imagen2.shape
# imagen_color = cv2.resize(imagen_color, (ancho, altura))
# imagen_rgb = cv2.resize(imagen_rgb, (ancho, altura))

# # Convertir la imagen en escala de grises a un formato de tres canales para poder concatenarla con las otras
# imagen_gris_3c = cv2.cvtColor(imagen2, cv2.COLOR_GRAY2BGR)

# # Concatenar las imágenes horizontalmente
# imagenes_concatenadas = np.hstack((imagen_rgb, imagen_color, imagen_gris_3c))

# # Agregar texto a cada imagen
# cv2.putText(imagenes_concatenadas, 'RGB', (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
# cv2.putText(imagenes_concatenadas, 'BGR', (ancho + 10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
# cv2.putText(imagenes_concatenadas, 'Escala de Grises', (2 * ancho + 10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)

# # Mostrar las imágenes concatenadas en una ventana
# cv2.imshow('Mostrar la imagen en RGB, BGR y escala de grises', imagenes_concatenadas)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %% [markdown]
# ### 2.3. Lectura de imagenes con matplotlib

# %%
# Si deseo que lo muestre directamente con Pyplot
imagen=mpi.imread('../imagenes/_lena.png') # Lee RGB
plt.figure(figsize=(3,3))
plt.imshow(imagen)
plt.title("Leer y mostrar con matplotlib")
plt.axis("off")
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
# Imagen en escala de grises , mostrar correctamente usando pyplot
imagen=mpi.imread('../imagenes/barbara.png') # Lee RGB

# %%
# Imagen en escala de grises , mostrar correctamente usando pyplot
import matplotlib.pyplot as plt
import matplotlib.image as mpi

# Lee la imagen, que ya debería estar en escala de grises
imagen_gris = mpi.imread('../imagenes/barbara.png')

# Asegúrate de que la imagen está en escala de grises verificando si tiene 2 dimensiones
if imagen_gris.ndim == 2:
    # Muestra la imagen en escala de grises
    plt.imshow(imagen_gris, cmap='gray')
    plt.axis('off')  # Oculta los ejes
    plt.show()
else:
    print("La imagen no está en escala de grises.")

# %%
# Imagen en escala de grises , mostrar correctamente usando pyplot
imagen=mpi.imread('../imagenes/barbara.png') # Lee RGB
imagen_rgb = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(3,3))
plt.imshow(imagen_rgb)
plt.title("Leer y mostrar con matplotlib")
plt.axis("off")
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
# Leer con matplotlib y mostrar correctamente con opencv
imagen=mpi.imread('../imagenes/_lena.png') # Lee RGB
imagen_rgb = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(3,3))
plt.imshow(imagen_rgb)
plt.title("Leer y mostrar con matplotlib")
plt.axis("off")


cv2.imshow('Imagenes Concatenadas', imagen_rgb)
cv2.waitKey(0) 
cv2.destroyAllWindows() # Para cerrar ventana

# %%
# Leer con matplotlib y mostrar correctamente con opencv
imagen=mpi.imread('../imagenes/_lena.png') # Lee RGB

# %% [markdown]
# ### 2.4. Lectura de imagenes con PIL

# %%
# Poder mostrar desde Fotos
im=Image.open('../imagenes/_lena.png')
im.show()

# %% [markdown]
# ### 2.5. Lectura de archivo de video

# %%
def rescale_frame(frame, op=0, ratio=0.75,W=200,H=100):
    if op==0:
        width = int(frame.shape[1] * ratio)
        height = int(frame.shape[0] * ratio)
        resized_frame= cv2.resize(frame, (width, height), interpolation=cv2.INTER_AREA)
    else:
        resized_frame = cv2.resize(frame, (W, H), interpolation=cv2.INTER_LINEAR)
    return resized_frame

# %%
# Inicializar lectura de archivo de video
vreader = cv2.VideoCapture('../imagenes/Isles of Glencoe.mp4')

#Mostrar el video frame by frame
while True:
    ret, frame = vreader.read()
    if not ret:
        break
    frame = rescale_frame(frame, ratio=0.75)
    cv2.imshow('Mi video', frame) # Mostrar el frame

    # Salimos presionando: x
    if cv2.waitKey(1) & 0xFF == ord('x'):
        break

# Liberar el lector de video
vreader.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### 2.6. Lectura de video en tiempo real

# %%
# Inicializar captura de video en tiempo real solo si tienes una camara instalada

# %% [markdown]
# ## 3. Crear y grabar

# %% [markdown]
# ### 3.1. Imagen en escala de grises

# %%
d=(80,80)
img=np.zeros(d)
for i in range(20,61):
    for j in range(20,61):
        img[i,j]=255-i-j
img[30:51,30:51]=0;
img=np.uint8(img)
plt.figure(figsize=(3,3))
plt.imshow(img,cmap=plt.cm.gray)
plt.axis("off")
# Out:
# (-0.5, 79.5, 79.5, -0.5)

# %% [markdown]
# ### 3.2. Imagen a color

# %%
f=c=80
d=(f,c,3)
img=np.zeros(d,dtype=np.uint8)
for i in range(20,61):
    for j in range(20,61):
        img[i,j,0]=img[i,j,1]=0
        img[i,j,2]=255
img[30:51,30:51,0:3]=[255,0,0];
plt.figure(figsize=(3,3))
plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 79.5, 79.5, -0.5)

# %% [markdown]
# ### 3.3. Grabar imagen

# %% [markdown]
# Es mas eficiente que el anterior porque esta vectorizado

# %%
f=c=80
d=(f,c,3)
img=np.zeros(d,dtype=np.uint8)
img[20:61,20:61,0:3]=[0,0,255]
img[30:51,30:51,0:3]=[255,0,0]
cv2.imwrite('MiImagen.png',img) # Grabar imagen directamente
# Out:
# True

# %%
#Leer la imagen guardada
imagen=cv2.imread('MiImagen.png')
plt.figure(figsize=(3,3))
plt.imshow(imagen)
plt.title("Imagen RGB")
plt.axis("off")
# Out:
# (-0.5, 79.5, 79.5, -0.5)

# %%
# Ahora lea la imagen usando opencv y muestrela usando opencv correctamente, utilice resize de  (400,400)
imagen=cv2.imread('MiImagen.png')

# %%
import cv2

imagen = cv2.imread('MiImagen.png')

imagen_redimensionada = cv2.resize(imagen, (400, 400))

imagen_rgb = cv2.cvtColor(imagen_redimensionada, cv2.COLOR_BGR2RGB)
cv2.imshow('Imagen Redimensionada', imagen_rgb)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

# Leer la imagen
imagen = cv2.imread('MiImagen.png')

# Verificar que la imagen ha sido cargada correctamente
if imagen is not None:
    # Redimensionar la imagen a 400x400
    imagen_redimensionada = cv2.resize(imagen, (400, 400))

    # Mostrar la imagen redimensionada
    cv2.imshow('Imagen Redimensionada', imagen_redimensionada)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
else:
    print("Error: no se ha podido cargar la imagen. Verifique la ruta del archivo.")

# %%
import cv2

# Leer la imagen
imagen = cv2.imread('MiImagen.png')

# Redimensionar la imagen
imagen_resized = cv2.resize(imagen, (400, 400))

# Mostrar la imagen
cv2.imshow('Imagen RGB', imagen_resized)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Poder mostrar desde Fotos imagen generada usando PIL
im=Image.open('MiImagen.png')  # observese que se ha guardado como BGR

# %% [markdown]
# ### 3.4. Grabar video

# %%
# Inicializar captura de video en tiempo real solo si tienes una camara instalada
camara = 0   # La camara por defecto es cero
vreader = cv2.VideoCapture(camara)

# Crear VideoWriter:
output = 'captura.mp4'
fps = 30  # Frames x segundo
size = (640, 480)  # Frame size
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec para formato MP4
vwriter = cv2.VideoWriter(output, fourcc, fps, size)

while True:
    ret, frame = vreader.read()
    if not ret:
        break
    cv2.imshow('Captura en tiempo real', frame) # Mostrar el frame
    vwriter.write(frame) # Grabamos el frame
    # Salimos presionando: x
    if cv2.waitKey(1) & 0xFF == ord('x'):
        break
# Liberar el lector de video
vreader.release()
vwriter.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## 4.Estructura de una imagen

# %% [markdown]
# ### 4.1. Tamaño de la imagen.

# %% [markdown]
# El número de pixeles de la imagen: filas(alto) x columnas (ancho).

# %%
location="../imagenes/_lena.png"
imagen= cv2.imread(location)

plt.figure(figsize=(3,3))
plt.imshow(cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB))
plt.axis("off")

print(imagen.dtype)
print('Dimension:',imagen.shape[0],'x',imagen.shape[1])  # height x width
print(imagen.shape[0]*imagen.shape[1])  # resolucion   print(int(imagen.size/imagen.ndim))
# Out:
# uint8
# Dimension: 512 x 512
# 262144

# %% [markdown]
# Cuando opencv se muestra en una ventana Los colores se muestran en el espacio RGB pero cuando se quiere representar en el mismo Júpiter notebook  con Plot Se muestran en el espacio BGR

# %%
location="../imagenes/_lena.png"
imagen= cv2.imread(location)

plt.figure(figsize=(3,3))
# plt.imshow(cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB))
plt.imshow(imagen)
plt.axis("off")

print(imagen.dtype)
print('Dimension:',imagen.shape[0],'x',imagen.shape[1])  # height x width
print(imagen.shape[0]*imagen.shape[1])  # resolucion   print(int(imagen.size/imagen.ndim))
# Out:
# uint8
# Dimension: 512 x 512
# 262144
