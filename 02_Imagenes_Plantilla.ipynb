# %% [markdown]
# # Manipulación de Imagenes

# %% [markdown]
# ## 1. Librerias

# %%
# !pip install matplotlib
# !pip install mahotas
# !pip install cv
# !pip install scikit-image
# !pip install opencv-python
# Out:
# Requirement already satisfied: matplotlib in c:\programs\anaconda3\envs\nuevo10\lib\site-packages (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programs\anaconda3\envs\nuevo10\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\programs\anaconda3\envs\nuevo10\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programs\anaconda3\envs\nuevo10\lib\site-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programs\anaconda3\envs\nuevo10\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\programs\anaconda3\envs\nuevo10\lib\site-packages (from matplotlib) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in c:\programs\anaconda3\envs\nuevo10\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=8 in c:\programs\anaconda3\envs\nuevo10\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programs\anaconda3\envs\nuevo10\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programs\anaconda3\envs\nuevo10\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\programs\anaconda3\envs\nuevo10\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: mahotas in c:\programs\anaconda3\envs\nuevo10\lib\site-packages (1.4.13)
# Requirement already satisfied: numpy in c:\programs\anaconda3\envs\nuevo10\lib\site-packages (from mahotas) (1.26.3)
# Requirement already satisfied: cv in c:\programs\anaconda3\envs\nuevo10\lib\site-packages (1.0.0)
# Requirement already satisfied: scikit-image in c:\programs\anaconda3\envs\nuevo10\lib\site-packages (0.22.0)
# Requirement already satisfied: numpy>=1.22 in c:\programs\anaconda3\envs\nuevo10\lib\site-packages (from scikit-image) (1.26.3)
# Requirement already satisfied: scipy>=1.8 in c:\programs\anaconda3\envs\nuevo10\lib\site-packages (from scikit-image) (1.12.0)
# Requirement already satisfied: networkx>=2.8 in c:\programs\anaconda3\envs\nuevo10\lib\site-packages (from scikit-image) (3.2.1)
# Requirement already satisfied: pillow>=9.0.1 in c:\programs\anaconda3\envs\nuevo10\lib\site-packages (from scikit-image) (10.2.0)
# Requirement already satisfied: imageio>=2.27 in c:\programs\anaconda3\envs\nuevo10\lib\site-packages (from scikit-image) (2.34.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\programs\anaconda3\envs\nuevo10\lib\site-packages (from scikit-image) (2024.2.12)
# Requirement already satisfied: packaging>=21 in c:\programs\anaconda3\envs\nuevo10\lib\site-packages (from scikit-image) (23.1)
# Requirement already satisfied: lazy_loader>=0.3 in c:\programs\anaconda3\envs\nuevo10\lib\site-packages (from scikit-image) (0.3)
# Requirement already satisfied: opencv-python in c:\programs\anaconda3\envs\nuevo10\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in c:\programs\anaconda3\envs\nuevo10\lib\site-packages (from opencv-python) (1.26.3)

# %%
import numpy as np
import cv2 as cv2
import io as io
# %matplotlib inline 
import matplotlib.pyplot as plt
import matplotlib.image as mpi
from PIL import Image 
import mahotas
import mahotas.demos

# %% [markdown]
# ## 5. Procesamiento de imágenes

# %%
# Convertir imagen en arreglo numpy
ruta="./imagenes/_lena.png"
gris = cv2.imread(ruta,0)

print("Imagen original:", np.shape(original))
print("Imagen en escala de grises",np.shape(gris))
# Out:
# Imagen original: (512, 512, 3)
# Imagen en escala de grises (512, 512)

# %% [markdown]
# Recordando lo aprendido en computación grafica, los conceptos se conservan de manera general.
# * Traslación
# * Rotación
# * Escalamiento

# %%
# Rotación
ruta="./imagenes/42044.jpg"
im = cv2.imread(ruta)
print("Imagen A: ", np.shape(im))

height, width = im.shape[:2]
center = (width/2, height/2)
angle =45
scale = 1.0
rotation_matrix = cv2.getRotationMatrix2D(center, angle, scale)
rotated_image = cv2.warpAffine(im, rotation_matrix, (width, height), borderMode=cv2.BORDER_CONSTANT)

plt.figure(figsize=(9,3))
plt.subplot(1,3,1)
plt.imshow(cv2.cvtColor(im,cv2.COLOR_BGR2RGB))
plt.axis("off")

plt.subplot(1,3,2)
plt.imshow(cv2.cvtColor(rotated_image,cv2.COLOR_BGR2RGB))
plt.axis("off")
# Out:
# Imagen A:  (321, 481, 3)
# (-0.5, 480.5, 320.5, -0.5)

# %% [markdown]
# ### 5.5. Filtros

# %% [markdown]
# Existen diversos tipos de ruido como: sal y pimienta, gaussiano, speckle.

# %%
#### Ruido
from skimage.util import random_noise

noisy_image = random_noise(gris, mode='s&p',amount=0.01)
noisy_image=np.uint8(noisy_image*255)

plt.figure(figsize=(12,3))

plt.subplot(1,3,1)
plt.imshow(gris,cmap=plt.cm.gray)
plt.axis("off")

plt.subplot(1,3,2)
plt.imshow(noisy_image,cmap=plt.cm.gray)
plt.axis("off")
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %% [markdown]
# #### 5.5.1. Filtros dominio espacial

# %%
denoised_image1 = cv2.GaussianBlur(noisy_image, (5, 5), 0)
denoised_image2 = cv2.medianBlur(noisy_image,ksize=5)

plt.figure(figsize=(16,4))

#completar
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %% [markdown]
# #### 6.2.2. filtros dominio de la frecuencia

# %%
# Calcular la transformada de Fourier 2D
f_transform = np.fft.fft2(noisy_image)
f_shift = np.fft.fftshift(f_transform)

# Crear un kernel para filtro paso-bajo (suavizado)
f, c = noisy_image.shape
center_f, center_c = f // 2, c // 2
radius = 50  # Ajusta el tamaño del filtro
mask = np.zeros((f, c), dtype=np.uint8)
mask[center_f - radius:center_f + radius, center_c - radius:center_c + radius] = 1

# Aplicar el filtro en el dominio de la frecuencia
f_filtered = f_shift * mask

# Calcular la transformada inversa
denoised_image = np.abs(np.fft.ifft2(np.fft.ifftshift(f_filtered)))

# Mostrar la imagen filtrada
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %% [markdown]
# ### 5.6. Detectores de bordes

# %%
#Completar los demas detectores de bordes no olvidar tomar en cuenta la información brindada de clase teorica 
# Para los detectores de primer orden apoyarse de filter2D
laplacian=np.uint8(np.abs((cv2.Laplacian(gris, cv2.CV_64F))))
canny= np.uint8(cv2.Canny(gris, 100, 200))

# Mostrar bordes
plt.figure(figsize=(12,3))

plt.subplot(1,3,1)
plt.imshow(gris,cmap=plt.cm.gray)
plt.axis("off")

plt.subplot(1,3,2)
plt.imshow(laplacian, cmap=plt.cm.gray)
plt.axis("off")

plt.subplot(1,3,3)
plt.imshow(canny, cmap=plt.cm.gray)
plt.axis("off")
# Out:
# (-0.5, 511.5, 511.5, -0.5)
